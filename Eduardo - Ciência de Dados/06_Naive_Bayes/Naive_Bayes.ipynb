# %% [markdown]
# # **Naive Bayes**

# %% [markdown]
# https://www.youtube.com/watch?v=qOIZbJ0IH2k

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cancer.csv', sep=';')
df['diagnose'] = df['diagnose'].replace({1:'M', 0:'B'})
df.head()
# Out:
#          id diagnose  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        M        17.99         10.38          122.80     1001.0
# 1    842517        M        20.57         17.77          132.90     1326.0
# 2  84300903        M        19.69         21.25          130.00     1203.0
# 3  84348301        M        11.42         20.38           77.58      386.1
# 4  84358402        M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df['diagnose'] = df['diagnose'].replace({'M':1, 'B':0})
df.head()
# Out:
#          id  diagnose  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         1        17.99         10.38          122.80     1001.0
# 1    842517         1        20.57         17.77          132.90     1326.0
# 2  84300903         1        19.69         21.25          130.00     1203.0
# 3  84348301         1        11.42         20.38           77.58      386.1
# 4  84358402         1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnose                 569 non-null    int64
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe().T
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# diagnose                 569.0  3.725835e-01  4.839180e-01     0.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# ...

# %%
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(df, title='Relatório Base de Dados', html={'style':{'full_width':True}})
profile.to_notebook_iframe()
profile.to_file(output_file='Relatório Base de Dados.html')

# %%
df = df.drop(columns=['id', 'F33'], axis=1)

# %%
M = df[(df['diagnose'] == 1)]

# %%
B = df[(df['diagnose'] == 0)]

# %%
plt.title('Tumar Malígno vs Benigno')
plt.xlabel('Radius Mean')
plt.ylabel('Texture Mean')

plt.scatter(x=M['radius_mean'], y=M['texture_mean'], c='red', alpha=0.3, label='Maligno' )
plt.scatter(x=B['radius_mean'], y=B['texture_mean'], c='lime', alpha=0.3, label='Benigno' )

plt.legend()
plt.show()

# %%
X = df.drop(columns=['diagnose'], axis=1)
y = df['diagnose']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaler = scaler.fit_transform(X)

# %%
df2 = pd.DataFrame(X_scaler, columns=X.columns)
df2.describe().T
# Out:
#                          count          mean      std       min       25%  \
# radius_mean              569.0 -1.373633e-16  1.00088 -2.029648 -0.689385
# texture_mean             569.0  6.868164e-17  1.00088 -2.229249 -0.725963
# perimeter_mean           569.0 -1.248757e-16  1.00088 -1.984504 -0.691956
# area_mean                569.0 -2.185325e-16  1.00088 -1.454443 -0.667195
# smoothness_mean          569.0 -8.366672e-16  1.00088 -3.112085 -0.710963
# compactness_mean         569.0  1.873136e-16  1.00088 -1.610136 -0.747086
# concavity_mean           569.0  4.995028e-17  1.00088 -1.114873 -0.743748
# concave points_mean      569.0 -4.995028e-17  1.00088 -1.261820 -0.737944
# symmetry_mean            569.0  1.748260e-16  1.00088 -2.744117 -0.703240
# fractal_dimension_mean   569.0  4.745277e-16  1.00088 -1.819865 -0.722639
# radius_se                569.0  2.372638e-16  1.00088 -1.059924 -0.623571
# texture_se               569.0 -1.123881e-16  1.00088 -1.554264 -0.694809
# ...

# %%
from sklearn.model_selection import train_test_split

X = X_scaler
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### **Modelo Naive Bays**

# %%
from sklearn.naive_bayes import GaussianNB

modelo = GaussianNB()
modelo.fit(Xtrain, ytrain)
# Out:
# GaussianNB()

# %%
ypred = modelo.predict(Xtest)

# %% [markdown]
# ### **Verificando a Assertividade**

# %%
print('Assertividade: %.2f%%' % (modelo.score(Xtest, ytest) * 100) )
# Out:
# Assertividade: 96.49%
